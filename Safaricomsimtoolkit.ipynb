# %%
from datetime import datetime
import pytz


def get_date_time():
  eat = pytz.timezone("Africa/Nairobi")
  date_and_time_now = str(datetime.now(eat))
  date_now = date_and_time_now.split(" ")[0]
  time_now = date_and_time_now.split(" ")[1]
  time_now = time_now.split(".")[0]
  return date_now, time_now




print(get_date_time())

date_now,  time_now = get_date_time()
print(f"The date today is {date_now}")
print(f"The time is {time_now}")
# Out:
# ('2026-01-30', '08:30:19')
# The date today is 2026-01-30
# The time is 08:30:19

# %%
from IPython.core.debugger import make_arrow
import os
from datetime import datetime
import pytz
import random
import string

def clear():
    os.system("clear")

def check_pin(mpesa_pin):
  user_pin = int(input("Enter your pin here : "))
  if user_pin == mpesa_pin:
    return True
  else:
    return False

def get_date_time():
  eat = pytz.timezone("Africa/Nairobi")
  date_and_time_now = str(datetime.now(eat))
  date_now = date_and_time_now.split(" ")[0]
  time_now = date_and_time_now.split(" ")[1]
  time_now = time_now.split(".")[0]
  return date_now, time_now

def generate_transaction_code():
  year_today = date_now.split("-")[0]
  month_today = date_now.split("-")[1]
  day_today = date_now.split("-")[2]

  year_dict = {
      "2027": "V",
      "2026": "U",
      "2025": "T",
      "2024": "S"
  }

  month_dict = {
      "01": "A",
      "02": "B",
      "03": "C",
      "04": "D",
      "05": "E",
      "06": "F",
      "07": "G",
      "08": "H",
      "09": "I",
      "10": "J",
      "11": "K",
      "12": "L"
  }

  day_dict = {
      "01": "2",
      "03": "3",
      "04": "4",
      "05": "5",
      "06": "6",
      "07": "7",
      "08": "8",
      "09": "9",
      "10": "A",
      "11": "B",
      "12": "C",
      "13": "D",
      "14": "E",
      "15": "F",
      "16": "G",
      "17": "H",
      "18": "I",
      "19": "J",
      "20": "K",
      "21": "L",
      "22": "M",
      "23": "N",
      "24": "O",
      "25": "P",
      "26": "Q",
      "27": "R",
      "28": "S",
      "29": "T",
      "30": "U",
      "31": "V"
  }


  first_xter = year_dict[year_today]
  second_xter = month_dict[month_today]
  third_xter = day_dict[day_today]

  permanent = "5Q"
  random_part = ''.join(random.choices(string.ascii_uppercase + string.digits, k=5))

  transaction_code = first_xter + second_xter + third_xter + permanent + random_part
  return transaction_code

def get_transaction_cost(amount):
  if amount <= 100:
    return 0
  elif amount <= 500:
    return 7
  elif amount <= 1000:
    return 13
  elif amount <= 5000:
    return 57
  else:
    return 100

mpesa_balance = 5000
mpesa_pin = 3456
max_transaction = 500000

print("Safaricom SIM Toolkit")

main_options = input("Enter an Option:\n1. Safaricom+\n2. M-Pesa\n")
clear()

if main_options == "1":
    safaricom_options = input("Select an Option:\n1. My Account\n2. M-Banking Services\n")
    clear()
    if safaricom_options == "1":
        my_account_options = input(
            "Select an Option:\n1. Balance Inquiry\n2. Top-Up\n3. Self Care\n4. Customer Care\n")
        clear()
        if my_account_options == "1":
            print("Balance Inquiry")
        elif my_account_options == "2":
            print("Top Up")
        elif my_account_options == "3":
            print("Self Care")
        elif my_account_options == "4":
            print("Customer Care")

    elif safaricom_options == "2":
        m_banking_options = input(
            "Select an Option:\n1. Barclays Bank\n2. Co-op Bank\n3. DTB\n4. Eco Bank\n5. Equity Bank\n6. Family Bank\n7. I&M Bank\n8. More\n")
        clear()
        if m_banking_options == "1":
            print("Barclays Bank")
        elif m_banking_options == "2":
            print("Co-op Bank")
        elif m_banking_options == "3":
            print("DTB")
        elif m_banking_options == "4":
            print("Eco Bank")
        elif m_banking_options == "5":
            print("Equity Bank")
        elif m_banking_options == "6":
            print("Family Bank")
        elif m_banking_options == "7":
            print("I&M Bank")
        elif m_banking_options == "8":
            print("More")

elif main_options == "2":
    mpesa_options = input(
        "Select an Option:\n1. Send Money\n2. Withdraw Cash\n3. Buy Airtime\n"
        "4. Loans and Savings\n5. Lipa na M-PESA\n6. My Account\n")
    clear()
    if mpesa_options == "1":
       phone_number = input("Enter the phone number here : ")
       amount = int(input("Enter the amount here : "))
       transaction_cost = get_transaction_cost(amount)
       if check_pin(mpesa_pin) and amount + transaction_cost <= mpesa_balance:
        mpesa_balance -= amount
        mpesa_balance -= transaction_cost
        max_transaction -= amount
        max_transaction -= transaction_cost
        date_now, time_now = get_date_time()
        code = generate_transaction_code()
        print(f"{code} Confirmed. You have successfully sent Ksh. {amount} to John Doe {phone_number}.Transaction cost is {transaction_cost}. Your balance is Ksh. {mpesa_balance}. On {time_now} at {date_now}. Maximum amount of money you can send is Ksh. {max_transaction}")
       else:
        print("Transaction failed. Incorrect PIN")


       #print(f"You have sent {amount} to {phone_number}")

    elif mpesa_options == "2":
        withdraw_options = input("Select an Option:\n1. From Agent\n2. From ATM\n")
        clear()
        if withdraw_options == "1":
            print("Withdraw from Agent")
            agnt_no = input("Enter the agent number here : ")
            str_no = input("Enter the store number here : ")
            amount = float(input("Enter amount here : "))
            transaction_cost = get_transaction_cost(amount)
            if check_pin(mpesa_pin) and amount <= mpesa_balance and amount + transaction_cost <= max_transaction:
              mpesa_balance -= amount
              mpesa_balance -= transaction_cost
              max_transaction -= amount
              max_transaction -= transaction_cost
              date_now, time_now = get_date_time()
              code = generate_transaction_code()
              print(f"{code} comfirmed. You have withrawn {amount} from {agnt_no}. On {date_now} at {time_now}. Your balance is {mpesa_balance}. Transaction cost is {get_transaction_cost}. Maximum amount you can withdraw is {max_transaction}")

        elif withdraw_options == "2":
            print("Withdraw from ATM")


    elif mpesa_options == "3":
        airtime_options = input("Select an Option:\n1. My Phone\n2. Other Number\n")
        clear()
        if airtime_options == "1":
            print("Buy Airtime for my phone")
        elif airtime_options == "2":
            print("Buy Airtime for other number")
    elif mpesa_options == "4":
        loans_savings_options = input("Select an Option:\n1. M-Shwari\n2. KCB M-PESA\n")
        clear()
        if loans_savings_options == "1":
            mshwari_options = input(
                "Enter an Option:\n1. Send to M-Shwari\n2. Withdraw from M-Shwari\n3. Lock Savings Account\n4. Loan @9% for 30 days\n5. Check balance\n6. Mini Statement\n")
            clear()
            if mshwari_options == "1":
                print("Send to M-Shwari")
            elif mshwari_options == "2":
                print("Withdraw from M-Shwari")
            elif mshwari_options == "3":
                lock_acc_options = input(
                    "Enter an Option:\n1. Open Account\n2. Save\n3. Withdraw\n4. Check Balance\n5. Mini Statement\n")
                clear()
                if lock_acc_options == "1":
                    print("Open Account")
                elif lock_acc_options == "2":
                    print("Save")
                elif lock_acc_options == "3":
                    print("Withdraw")
                elif lock_acc_options == "4":
                    print("Check Balance")
                elif lock_acc_options == "5":
                    print("Mini Statement")
            elif mshwari_options == "4":
                mshwari_loan_options = input(
                    "Enter an Option:\n1. Request Loan\n2. Pay Loan\n3. Check Loan Limit\n4. Loan Balance")
                if mshwari_loan_options == "1":
                  print("Request Loan")
                elif mshwari_loan_options == "2":
                    pay_mshwari_loan_options = input("Enter the Option:\n1. Pay Via Mpesa\n2. Pay Via Mshwari")
                    if pay_mshwari_loan_options == "1":
                      print("Pay Via Mpesa")
                    elif pay_mshwari_loan_options == "2":
                      print("Pay Via Mshwari")
                elif mshwari_loan_options == "3":
                    print(f"Your Mshwari Loan Limit is ...")
                elif mshwari_loan_options == "4":
                    print("Loan Balance")
            elif mshwari_options == "5":
                print("Your M-shwari balance is ...")
            elif mshwari_options == "6":
                print("Mini Statement")
        elif loans_savings_options == "2":
            kcb_mpesa_options = input(
                "Enter an Option:\n1. Deposit from M-Pesa\n2. Withdraw to M-Pesa\n3. Loan @8.93% for 30 Days\n4. Fixed Savings Account\n5. My Account\n")
            clear()
            if kcb_mpesa_options == "1":
                print("Deposit from M-Pesa")
            elif kcb_mpesa_options == "2":
                print("Withdraw to M-Pesa")
            elif kcb_mpesa_options == "3":
                print("Loan @8.93% for 30 days")
            elif kcb_mpesa_options == "4":
                print("Fixed Savings Account")
            elif kcb_mpesa_options == "5":
                print("My Account")
    elif mpesa_options == "5":
        lipa_na_mpesa_options = input(
            "Enter an Option:\n1. Pay Bill\n2. Buy Goods and Services\n3. Pochi la Biashara\n")
        clear()
        if lipa_na_mpesa_options == "1":
            print("Pay Bill")
            biz_no = input("Enter the business number here : ")
            acct_no = input("Enter the account number here : ")
            amount = float(input("Enter the amount here : "))
            if check_pin(mpesa_pin) and amount <= mpesa_balance and amount <= max_transaction:
              mpesa_balance -= amount
              max_transaction -= amount
              date_now, time_now = get_date_time()
              code = generate_transaction_code()
              print(f"{code} Confirmed. You have successfully sent Ksh. {amount} to {biz_no}. On {date_now} at {time_now}. Your balance is {mpesa_balance}. Maximum youcan transact is {max_transaction}) ")
            else:
                print("Transaction failed. Incorrect PIN")
        elif lipa_na_mpesa_options == "2":
            print("Buy goods and services")
        elif lipa_na_mpesa_options == "3":
            print("Pochi la Biashara")
    elif mpesa_options == "6":
        my_account_options = input(
            "Enter an Option:\n1. Mini Statement\n2. M-Pesa PIN Manager\n3. Change Language\n4. Update Customer Menu\n5. Check Balance")
        clear()
        if my_account_options == "1":
            print("Mini Statement")
        elif my_account_options == "2":
            print("Mpesa PIN Manager")
        elif my_account_options == "3":
            print("Change Language")
        elif my_account_options == "4":
            print("Update Customer Menu")
        elif my_account_options == "5":
            print("Check balance")
# Out:
# Safaricom SIM Toolkit
# Enter an Option:
# 1. Safaricom+
# 2. M-Pesa
# 2
# Select an Option:
# 1. Send Money
# 2. Withdraw Cash
# 3. Buy Airtime
# 4. Loans and Savings
# 5. Lipa na M-PESA
# 6. My Account
# 1
# Enter the phone number here : 0733334333
# Enter the amount here : 4000
# Enter your pin here : 3456
# UAU5QYLFJ4 Confirmed. You have successfully sent Ksh. 4000 to John Doe 0733334333.Transaction cost is 57 Your balance is Ksh. 943. On 09:40:00 at 2026-01-30. Maximum amount of money you can send is Ksh. 495943
