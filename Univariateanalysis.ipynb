# %% [markdown]
# <a href="https://colab.research.google.com/github/scxbbard/Data-science-classes/blob/main/Univariateanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##loading the dataset
import pandas as pd
df = pd.read_csv("/content/day.csv")

# %%
#import libraries needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the first rows 10 of the dataset
df.head(366)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
# 364      365  2011-12-31       1   0    12        0        6           0
# 365      366  2012-01-01       1   1     1        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
###loading last 10 rows
df.tail(10)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 721      722  2012-12-22       1   1    12        0        6           0
# 722      723  2012-12-23       1   1    12        0        0           0
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 725      726  2012-12-26       1   1    12        0        3           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 721           1  0.265833  0.236113  0.441250   0.407346     205        1544
# ...

# %%
df.shape ###shows as the number of rows and columns
# Out:
# (731, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
##checking the descriptive data
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# Univariate analysis - Non visual

# %%
df['cnt'].describe()
# Out:
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
features =['instant', 'temp', 'atemp', 'hum', 'windspeed',
       'casual', 'registered', 'cnt']
for i, feature in enumerate(features):
    print(f"\nSummary statistics for {feature}")
    print(df[feature].describe())

    plt.figure(figsize=(8,5))
    sns.histplot(df[feature], bins=30, kde=True, color="blue")
    plt.title(f"Distribution of {feature}")
    plt.xlabel(f"{feature}")
    plt.ylabel("Frequency")
    plt.show()

    ###Boxplots
    ####Boxplots
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[feature], color="red")
    plt.title(f"Boxplot of {feature}")
    plt.show()
# Out:
# Summary statistics for instant
# count    731.000000
# mean     366.000000
# std      211.165812
# min        1.000000
# 25%      183.500000
# 50%      366.000000
# 75%      548.500000
# max      731.000000
# Name: instant, dtype: float64
# Summary statistics for temp
# count    731.000000
# mean       0.495385
# std        0.183051
# min        0.059130
# 25%        0.337083
# 50%        0.498333
# 75%        0.655417
# max        0.861667
# Name: temp, dtype: float64
# Summary statistics for atemp
# count    731.000000
# mean       0.474354
# std        0.162961
# min        0.079070
# 25%        0.337842
# 50%        0.486733
# 75%        0.608602
# max        0.840896
# Name: atemp, dtype: float64
# Summary statistics for hum
# count    731.000000
# mean       0.627894
# std        0.142429
# min        0.000000
# 25%        0.520000
# 50%        0.626667
# 75%        0.730209
# max        0.972500
# Name: hum, dtype: float64
# Summary statistics for windspeed
# ...
